# %% [markdown]
# ### Analysing Customr Data

# %%
# !pip install --upgrade seaborn
# Out:
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.9.0)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
cust_data = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/customers_data.csv")

# %%
cust_data.head()
# Out:
#    Unnamed: 0  purch_amt  gender card_on_file   age  days_since_last_purch  \
# 0           0      19.58    male           no  31.0                   35.0
# 1           1      65.16    male          yes  23.0                   61.0
# 2           2      40.60  female           no  36.0                   49.0
# 3           3      38.01    male          yes  47.0                   57.0
# 4           4      22.32  female          yes   5.0                   39.0
#
#    loyalty
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
cust_data.isnull().sum()
# Out:
# Unnamed: 0               0
# purch_amt                0
# gender                   0
# card_on_file             0
# age                      0
# days_since_last_purch    0
# loyalty                  0
# dtype: int64

# %%
sns.pairplot(cust_data)

# %%
cust_data.corr()
# Out:
#                        Unnamed: 0  purch_amt       age  days_since_last_purch  \
# Unnamed: 0               1.000000   0.000732 -0.001129               0.000263
# purch_amt                0.000732   1.000000  0.038749              -0.098926
# age                     -0.001129   0.038749  1.000000              -0.084457
# days_since_last_purch    0.000263  -0.098926 -0.084457               1.000000
# loyalty                  0.000528   0.216203  0.180061              -0.457012
#
#                         loyalty
# Unnamed: 0             0.000528
# purch_amt              0.216203
# age                    0.180061
# days_since_last_purch -0.457012
# loyalty                1.000000

# %% [markdown]
# There is a weak bivariate correlation between variables however value of some variable are normally distributed
