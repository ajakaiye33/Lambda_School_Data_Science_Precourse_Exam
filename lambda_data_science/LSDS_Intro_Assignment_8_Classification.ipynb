# %% [markdown]
# # Applying Logistics Regression on the Titanic Data set — Classification!

# %% [markdown]
# ## Assignment
#
# Run this cell to load the Titanic data:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
train, test = train_test_split(sns.load_dataset('titanic').drop(columns=['alive']))
target = 'survived'

# %% [markdown]
# Some EDA:

# %%
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 70          0       2    male  32.0      0      0  10.5000        S  Second
# 81          1       3    male  29.0      0      0   9.5000        S   Third
# 389         1       2  female  17.0      0      0  12.0000        C  Second
# 810         0       3    male  26.0      0      0   7.8875        S   Third
# 38          0       3  female  18.0      2      0  18.0000        S   Third
#
#        who  adult_male deck  embark_town  alone
# 70     man        True  NaN  Southampton   True
# 81     man        True  NaN  Southampton   True
# 389  woman       False  NaN    Cherbourg   True
# 810    man        True  NaN  Southampton   True
# 38   woman       False  NaN  Southampton  False

# %% [markdown]
# ## Replace the missing value under the age column with the average age

# %%
train_mean = train.age.mean()
train_mean
# Out:
# 29.448070500927646

# %%
test_mean = test.age.mean()
test_mean
# Out:
# 30.472342857142856

# %%
train.age.fillna(train_mean,inplace=True)
train.age.isnull().sum()
# Out:
# 0

# %%
test.age.fillna(test_mean, inplace=True)
test.age.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## How many survived?

# %%
 train.survived.value_counts()
# Out:
# 0    402
# 1    266
# Name: survived, dtype: int64

# %% [markdown]
# ### Preprocessing data

# %%
train.sex.replace({'female':0, 'male':1},inplace=True)

# %%
test.sex.replace({'female':0, 'male':1},inplace=True)

# %%
train['sex'] = train['sex'].astype(int)

# %%
test['sex'] = test['sex'].astype(int)

# %%
train['age'] = train['age'].astype(int)

# %%
test['age'] = test['age'].astype(int)

# %%
test.tail()
# Out:
#      survived  pclass  sex  age  sibsp  parch    fare embarked  class    who  \
# 555         0       1    1   62      0      0   26.55        S  First    man
# 660         1       1    1   50      2      0  133.65        S  First    man
# 132         0       3    0   47      1      0   14.50        S  Third  woman
# 61          1       1    0   38      0      0   80.00      NaN  First  woman
# 179         0       3    1   36      0      0    0.00        S  Third    man
#
#      adult_male deck  embark_town  alone
# 555        True  NaN  Southampton   True
# 660        True  NaN  Southampton  False
# 132       False  NaN  Southampton  False
# 61        False    B          NaN   True
# 179        True  NaN  Southampton   True

# %% [markdown]
# since we would be using the features of* age *and *sex* . Let's also do some EDA on them

# %% [markdown]
# ## Male Passengers

# %%
train[train.sex==0]
# Out:
#      survived  pclass  sex  age  sibsp  parch      fare embarked   class  \
# 389         1       2    0   17      0      0   12.0000        C  Second
# 38          0       3    0   18      2      0   18.0000        S   Third
# 700         1       1    0   18      1      0  227.5250        C   First
# 427         1       2    0   19      0      0   26.0000        S  Second
# 11          1       1    0   58      0      0   26.5500        S   First
# 423         0       3    0   28      1      1   14.4000        S   Third
# 257         1       1    0   30      0      0   86.5000        S   First
# 106         1       3    0   21      0      0    7.6500        S   Third
# 416         1       2    0   34      1      1   32.5000        S  Second
# 541         0       3    0    9      4      2   31.2750        S   Third
# 670         1       2    0   40      1      1   39.0000        S  Second
# 142         1       3    0   24      1      0   15.8500        S   Third
# 472         1       2    0   33      1      2   27.7500        S  Second
# 571         1       1    0   53      2      0   51.4792        S   First
# 608         1       2    0   22      1      2   41.5792        C  Second
# 540         1       1    0   36      0      2   71.0000        S   First
# 642         0       3    0    2      3      2   27.9000        S   Third
# 256         1       1    0   29      0      0   79.2000        C   First
# 345         1       2    0   24      0      0   13.0000        S  Second
# 559         1       3    0   36      1      0   17.4000        S   Third
# 268         1       1    0   58      0      1  153.4625        S   First
# 40          0       3    0   40      1      0    9.4750        S   Third
# 358         1       3    0   29      0      0    7.8792        Q   Third
# 779         1       1    0   43      0      1  211.3375        S   First
# 184         1       3    0    4      0      2   22.0250        S   Third
# 289         1       3    0   22      0      0    7.7500        Q   Third
# 85          1       3    0   33      3      0   15.8500        S   Third
# 546         1       2    0   19      1      0   26.0000        S  Second
# 717         1       2    0   27      0      0   10.5000        S  Second
# 796         1       1    0   49      0      0   25.9292        S   First
# ..        ...     ...  ...  ...    ...    ...       ...      ...     ...
# 727         1       3    0   29      0      0    7.7375        Q   Third
# 503         0       3    0   37      0      0    9.5875        S   Third
# 537         1       1    0   30      0      0  106.4250        C   First
# 443         1       2    0   28      0      0   13.0000        S  Second
# 862         1       1    0   48      0      0   25.9292        S   First
# 612         1       3    0   29      1      0   15.5000        Q   Third
# 18          0       3    0   31      1      0   18.0000        S   Third
# 133         1       2    0   29      1      0   26.0000        S  Second
# 419         0       3    0   10      0      2   24.1500        S   Third
# 272         1       2    0   41      0      1   19.5000        S  Second
# 585         1       1    0   18      0      2   79.6500        S   First
# 293         0       3    0   24      0      0    8.8500        S   Third
# 412         1       1    0   33      1      0   90.0000        Q   First
# 437         1       2    0   24      2      3   18.7500        S  Second
# 22          1       3    0   15      0      0    8.0292        Q   Third
# 269         1       1    0   35      0      0  135.6333        S   First
# 180         0       3    0   29      8      2   69.5500        S   Third
# 255         1       3    0   29      0      2   15.2458        C   Third
# 634         0       3    0    9      3      2   27.9000        S   Third
# 251         0       3    0   29      1      1   10.4625        S   Third
# 777         1       3    0    5      0      0   12.4750        S   Third
# 702         0       3    0   18      0      1   14.4542        C   Third
# 241         1       3    0   29      1      0   15.5000        Q   Third
# 750         1       2    0    4      1      1   23.0000        S  Second
# 417         1       2    0   18      0      2   13.0000        S  Second
# 483         1       3    0   63      0      0    9.5875        S   Third
# 383         1       1    0   35      1      0   52.0000        S   First
# 215         1       1    0   31      1      0  113.2750        C   First
# 431         1       3    0   29      1      0   16.1000        S   Third
# 319         1       1    0   40      1      1  134.5000        C   First
#
#        who  adult_male deck  embark_town  alone
# 389  woman       False  NaN    Cherbourg   True
# 38   woman       False  NaN  Southampton  False
# 700  woman       False    C    Cherbourg  False
# 427  woman       False  NaN  Southampton   True
# 11   woman       False    C  Southampton   True
# 423  woman       False  NaN  Southampton  False
# 257  woman       False    B  Southampton   True
# 106  woman       False  NaN  Southampton   True
# 416  woman       False  NaN  Southampton  False
# 541  child       False  NaN  Southampton  False
# 670  woman       False  NaN  Southampton  False
# 142  woman       False  NaN  Southampton  False
# 472  woman       False  NaN  Southampton  False
# 571  woman       False    C  Southampton  False
# 608  woman       False  NaN    Cherbourg  False
# 540  woman       False    B  Southampton  False
# 642  child       False  NaN  Southampton  False
# 256  woman       False  NaN    Cherbourg   True
# 345  woman       False    F  Southampton   True
# 559  woman       False  NaN  Southampton  False
# 268  woman       False    C  Southampton  False
# 40   woman       False  NaN  Southampton  False
# 358  woman       False  NaN   Queenstown   True
# 779  woman       False    B  Southampton  False
# 184  child       False  NaN  Southampton  False
# 289  woman       False  NaN   Queenstown   True
# 85   woman       False  NaN  Southampton  False
# 546  woman       False  NaN  Southampton  False
# 717  woman       False    E  Southampton   True
# 796  woman       False    D  Southampton   True
# ..     ...         ...  ...          ...    ...
# 727  woman       False  NaN   Queenstown   True
# 503  woman       False  NaN  Southampton   True
# 537  woman       False  NaN    Cherbourg   True
# 443  woman       False  NaN  Southampton   True
# 862  woman       False    D  Southampton   True
# 612  woman       False  NaN   Queenstown  False
# 18   woman       False  NaN  Southampton  False
# 133  woman       False  NaN  Southampton  False
# 419  child       False  NaN  Southampton  False
# 272  woman       False  NaN  Southampton  False
# 585  woman       False    E  Southampton  False
# 293  woman       False  NaN  Southampton   True
# 412  woman       False    C   Queenstown  False
# 437  woman       False  NaN  Southampton  False
# 22   child       False  NaN   Queenstown   True
# 269  woman       False    C  Southampton   True
# 180  woman       False  NaN  Southampton  False
# 255  woman       False  NaN    Cherbourg  False
# 634  child       False  NaN  Southampton  False
# 251  woman       False    G  Southampton  False
# 777  child       False  NaN  Southampton   True
# 702  woman       False  NaN    Cherbourg  False
# 241  woman       False  NaN   Queenstown  False
# 750  child       False  NaN  Southampton  False
# 417  woman       False  NaN  Southampton  False
# 483  woman       False  NaN  Southampton   True
# 383  woman       False  NaN  Southampton  False
# 215  woman       False    D    Cherbourg  False
# 431  woman       False  NaN  Southampton  False
# 319  woman       False    E    Cherbourg  False
#
# [244 rows x 14 columns]

# %% [markdown]
# ## Female passengers that survived and otherwise

# %%
train[train.sex==0].survived.value_counts()
# Out:
# 1    184
# 0     60
# Name: survived, dtype: int64

# %% [markdown]
# ## Male passengers that survived and otherwise

# %%
train[train.sex==1].survived.value_counts()
# Out:
# 0    342
# 1     82
# Name: survived, dtype: int64

# %%
train.survived.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Are there missing values under the sex column in the train and test data set?

# %%
train.sex.isnull().sum(), test.sex.isnull().sum()
# Out:
# (0, 0)

# %% [markdown]
# ## Are there missing values under the age column in the train and test data set?

# %%
train.age.isnull().sum(),test.age.isnull().sum()
# Out:
# (0, 0)

# %% [markdown]
# ## **Preparing the *male *sex for our model**

# %%
train[1] = train.sex == 1
test[1] = test.sex == 1

# %%
train[['sex', 1]].head()
# Out:
#      sex      1
# 70     1   True
# 81     1   True
# 389    0  False
# 810    1   True
# 38     0  False

# %% [markdown]
# ##  Applying Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

features = [1, 'age']
target = 'survived'

model = LogisticRegression()
model.fit(train[features], train[target])

# Train accuracy

y_true = train[target]
y_pred = model.predict(train[features])
print(f'Train Accuracy: {accuracy_score(y_true,y_pred)}')

# Test accuracy

y_true = test[target]
y_pred = model.predict(test[features])
print(f'Test Accuracy: {accuracy_score(y_true, y_pred)}')
# Out:
# Train Accuracy: 0.7874251497005988
# Test Accuracy: 0.7847533632286996
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ##  Applying Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import accuracy_score

features = [1, 'age']
target = 'survived'

# model = RandomForestRegressor()
threshold = 0
model = RandomForestClassifier()
model.fit(train[features], train[target])

# Train Accuracy
y_true = train[target]
y_pred = model.predict(train[features])
print(f'Train Accuracy:{accuracy_score(y_true, (y_pred>threshold))}')
#print(f'Train Accuracy:{accuracy_score(y_true,y_pred)}')



# Test Accuracy
y_true = test[target]
y_pred = model.predict(test[features])
print(f'Test Accuracy:{accuracy_score(y_true, (y_pred>threshold))}')
#print(f'Test Accuracy:{accuracy_score(y_true,y_pred)}')
# Out:
# Train Accuracy:0.8278443113772455
# Test Accuracy:0.7309417040358744
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
